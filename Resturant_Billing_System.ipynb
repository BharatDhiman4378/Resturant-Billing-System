# %%
import tkinter as tk

from tkinter import *
from tkinter import  messagebox
import random

import time;

import datetime

import mysql.connector

#*******************************************functions****************************************************************************

def _clear():
    expression = ""
    input_text1.set(0)
    input_text2.set(0)
    input_text3.set(0)
    input_text4.set(0)
    input_text5.set(0)
    input_text6.set("")
    input_text7.set("")
    input_text8.set(0)
    input_text9.set(0)
    input_text10.set(0)
    input_text11.set(0)
    input_text12.set(0)
    input_text13.set("")
    input_text14.set("")
    input_text15.set("")
    input_text16.set("")
    input_text17.set(0)
    input_text18.set(0)
    #txtReceipt.insert(0)
    

def cost_of_meal():
    
    z = field1.get()
    y = field2.get()
    x = field3.get()
    w = field4.get()
    s = field5.get()
    
    _vegburger     = 40
    _pizza         = 130
    _ChickenBurger = 50
    _chinese       = 80
    _gralicbread   = 45
    var1  = (float(_pizza) * float(z)) + (float(_vegburger) * float(y)) + (float(_ChickenBurger) * float(x)) + (float(_chinese)*float(w)) + (float(_gralicbread)* float(s))
    
    field6.insert(tk.END , var1)

    
def cost_of_drink():   
    a = field8.get()
    b = field9.get()
    c = field10.get()
    d = field11.get()
    e = field12.get()
    
    _milkshake         = 40
    _VanillaCone       = 50
    _ClassicVanilla    = 50
    _ButterscotchShake = 50
    _oreoshake         = 50
    var2 = (float(_milkshake) * float(a)) + (float(_VanillaCone) * float(b)) + (float(_ClassicVanilla) * (float(c)) + (float(_ButterscotchShake) * float(d)) + (float(_oreoshake) * float(e)) )
    field7.insert(tk.END,var2) 
    
def total_cost():
    f = field6.get()
    g = field7.get()
    var3 = float(f) + float(g)
    field20.insert(tk.END , var3)
    field14.insert(tk.END, var3)

def _tax():
    h = field20.get()
    var4 = (5 * float(h))/100
    field13.insert(tk.END , var4)
    
def _total():
    i = field13.get()
    j = field20.get()
    var5 = float(i) + float(j)
    field15.insert(tk.END , var5)
    
def iExit():
    iExit = tk.messagebox.askyesno("Exit Restaurant System" , "Confirm if you want to exit")
    if iExit > 0:
        window.destroy()
        return
    
def return_amount():
    ret1 = float(field15.get())
    ret2 = float(field17.get())
    ret_amt = ret2 - ret1
    field18.insert(tk.END,ret_amt)
    
def add_order():
    va1 = Recepit_Ref.get()
    va2 = input_text15.get()
    va3 = str(v.get())
    va4 = DateofOrder.get()
    va5 = TimeofOrder.get()
    paid1 = str()
    
    if va3 == "1":
        paid1 = "cash"
    elif va3 == "2":
        paid1 = "debit card" 
    elif va3 == "3":
        paid1 = "credit card"
    elif va3 == "4":
        paid1 = "UPI"  
    sql = "insert into billing(bill_no , total_cost, paid_through ,date_of_order , time_of_order) values(%s,%s,%s,%s,%s) "
    mycursor.execute(sql ,( va1,va2,paid1,va4,va5))
    mydb.commit()
                     
def show_data():
    z1 = int(field1.get())
    y1 = int(field2.get())
    x1 = int(field3.get())
    w1 = int(field4.get())
    s1 = int(field5.get())
    a1 = int(field8.get())
    b1 = int(field9.get())
    c1 = int(field10.get())
    d1 = int(field11.get())
    e1 = int(field12.get())
    var1_ = float(field6.get())
    var2_ = float(field7.get())
    txtReceipt.delete("1.0" , END)
    
    selected = str(v.get())
    paid = str()
    if selected == "1":
        paid = "cash"
    elif selected == "2":
        paid = "debit card" 
    elif selected == "3":
        paid = "credit card"
    elif selected == "4":
        paid = "UPI"  
        
    ran = random.randint(10908 , 500876)
    randomRef = str(ran)
    recepit_ref.set(randomRef)
    Recepit_Ref.set("BILL" + randomRef)
    
    txtReceipt.insert(END , '  \tWELCOME TO LIKE HOME RESTAURANT GROUP'   + "\n")
    txtReceipt.insert(END , '------------------------------------------------------------------------------------------------'+ "\n\n")
    txtReceipt.insert(END , '\tReceipt Ref::\t\t' + Recepit_Ref.get() + "--" + DateofOrder.get() + "--" + TimeofOrder.get() + "\n\n")
    txtReceipt.insert(END , '\tItems\t\t' + "Quantity\t\t"  +  "Price"  + "\n\n")
    if z1 > 0 :
        txtReceipt.insert(END , ' \tPizza\t\t '              + field1.get()  + "\t\t" + "Rs.130"  +   "\n\n")
    if y1 > 0:
         txtReceipt.insert(END , ' \tVeg.Burger\t\t '        + field2.get()  + "\t\t" + "Rs.40"   +    "\n\n")
    if x1 > 0:
        txtReceipt.insert(END , ' \tChicken Burger\t\t   '   + field3.get()  + "\t\t" + "Rs.50"   +    "\n\n")
    if w1 > 0:
        txtReceipt.insert(END , ' \tChinese\t\t '            + field4.get()  + "\t\t" + "Rs.80"   +    "\n\n")
    if s1 > 0:
        txtReceipt.insert(END , ' \tGralic Bread\t\t '       + field5.get()  + "\t\t" + "Rs.45"   +    "\n\n")
    if a1>0:
        txtReceipt.insert(END , ' \tMilk Shake\t\t '         + field8.get()  + "\t\t" + "Rs.40"   +    "\n\n")
    if b1 >0:
        txtReceipt.insert(END , ' \tVanilla Cone\t\t '       + field9.get()  + "\t\t" + "Rs.50"   +    "\n\n")
    if c1>0:
        txtReceipt.insert(END , ' \tClassic Vanilla\t\t '    + field10.get() + "\t\t" + "Rs.50"   +    "\n\n")
    if d1>0:
        txtReceipt.insert(END , ' \tButterscotch Shake\t\t ' + field11.get() + "\t\t" + "Rs.50"   +    "\n\n")
    if e1 > 0:
        txtReceipt.insert(END , ' \tOreo Shake\t\t '         + field12.get() + "\t\t" + "Rs.50"   +    "\n\n")
    txtReceipt.insert(END , '------------------------------------------------------------------------------------------------'+ "\n\n")
    if var1_ > 0.0:
        txtReceipt.insert(END , '\tcost of meal\t\t\t\t'  + "Rs."  +  field6.get()   +    "\n\n")
    if var2_ > 0.0:    
        txtReceipt.insert(END , '\tcost of drink\t\t\t\t' + "Rs."  +  field7.get()   +    "\n\n")
    txtReceipt.insert(END , '\tTax\t\t\t\t'               + "Rs."  +  field13.get()  +    "\n\n")
    txtReceipt.insert(END , '\tTotal cost\t\t\t\t'        + "Rs."  +  field15.get()  +    "\n\n")
    txtReceipt.insert(END , '\tAmount Paid\t\t\t\t'       + "Rs."  +  field17.get()  +    "\n\n")
    txtReceipt.insert(END , '\tPaid Through\t\t\t\t'      +  paid  +    "\n\n")
    
#*************************************************MAIN WINDOW *****************************************************************    
    
window = tk.Tk()
window.title("restaurant")                            
#window.minsize(300,300)
#window.maxsize(800,500)
window.geometry("400x200")
window.configure(bg="gainsboro")       #background color of main wimdow

input_text1 = IntVar()
input_text2= IntVar()
input_text3 = IntVar()
input_text4= IntVar()
input_text5 = IntVar()

lbl = Label(window, text="LIKE HOME RESTAURANT GROUP" , font= ( "Elephant" ,30, "bold"  ,"underline" ),bg="darkgray"  , fg = "white" )
lbl.grid(padx =300 , pady = 0)

DateofOrder = StringVar()
DateofOrder.set(time.strftime("%d/%m/%Y"))

TimeofOrder = StringVar()
TimeofOrder.set(time.strftime("%H:%M:%S"))
Recepit_Ref = StringVar()
recepit_ref = StringVar()

#---------------------------------------------------------------database-----------------------------------------------------------

mydb = mysql.connector.connect(host = "localhost",user = "root",password="@imbharat",database = "personal")
mycursor = mydb.cursor()

#**************************************************canvas1(meal)**********************************************************************

canv = Canvas(window , height = 200 , width = 320 , bg = "white"  )
canv.create_text( 160 , 20 ,text="MEALS",fill = "black" , font = ("Arial Black" , 14  , "underline" , "bold") )

canv.create_text( 34 , 60 ,text="Pizza",fill = "black" , font = ("Cambria Math" , 14 ) )

canv.create_text( 58 , 90 ,text="Veg.Burger",fill = "black" , font = ("Cambria Math" , 14 ) )

canv.create_text( 74 , 120 ,text="Chicken Burger",fill = "black" , font = ("Cambria Math" , 14 ) )

canv.create_text( 42 , 150 ,text="Chinese",fill = "black" , font = ("Cambria Math" , 14 ) )

canv.create_text( 60 , 180 ,text="Gralic Bread",fill = "black" , font = ("Cambria Math" , 14 ) )

frame1 =  Frame( window, height = 20 , width = 30 , bg= "light grey" , bd = 4 )
frame1.place(x= 310 , y = 150)

field1= Entry(frame1, font=('arial',12,'bold'),textvariable= input_text1, width = 3 , bg ="white",justify=LEFT , bd = -1 )
field1.pack()

frame2 =  Frame( window, height = 25 , width = 35 , bg= "light grey" , bd = 4 )
frame2.place(x= 310 , y = 180)

field2= Entry(frame2, font=('arial',12,'bold'),textvariable= input_text2, width = 3 , bg ="white",justify=LEFT , bd = -1 )
field2.pack()

frame3 =  Frame( window, height = 25 , width = 35 , bg= "light grey" , bd = 4 )
frame3.place(x= 310 , y = 210)

field3= Entry(frame3, font=('arial',12,'bold'),textvariable= input_text3, width = 3 , bg ="white",justify=LEFT , bd = -1 )
field3.pack()

frame4 =  Frame( window, height = 25 , width = 35 , bg= "light grey" , bd = 4 )
frame4.place(x= 310 , y = 240)

field4= Entry(frame4, font=('arial',12,'bold'),textvariable= input_text4, width = 3 , bg ="white",justify=LEFT , bd = -1 )
field4.pack()

frame5 =  Frame( window, height = 25 , width = 35 , bg= "light grey" , bd = 4 )
frame5.place(x= 310 , y = 270)


field5= Entry(frame5, font=('arial',12,'bold'),textvariable= input_text5, width = 3 , bg ="white",justify=LEFT , bd = -1 )
field5.pack()

canv.place(x = 50 , y = 100)


#*********************************************************canvas2(costofmeal)*******************************************************************


input_text6 = StringVar()
input_text7 = StringVar()
input_text16 = StringVar()

canva2 = Canvas(window , height = 100 , width = 320 , bg = "white")

canva2.create_text(60 , 15 , text = "Cost of Meal" , font = ("Cambria Math" , 14  ))

frame6 = Frame(window , height = 25 , width = 35 , bg = "light grey" , bd =4 )
frame6.place(x = 310 , y = 325)
field6 = Entry(frame6 , font=("Arial" , 12 , "bold" ) , textvariable= input_text6 ,bg ="white" , justify =LEFT , bd = -1  , width = 5)
field6.pack()



canva2.create_text(64 , 45 , text = "Cost of Drink" , font = ("Cambria Math" , 14  ))

frame7 = Frame(window , height = 25 , width = 35 , bg = "light grey" , bd =4 )
frame7.place(x = 310 , y = 355)
field7 = Entry(frame7 , font=("Arial" , 12 , "bold" ) ,textvariable= input_text7, bg ="white" , justify =LEFT , bd = -1 , width = 5)
field7.pack()




canva2.create_text(54 , 75 , text = "Total Cost" , font = ("Cambria Math" , 14  ))

frame20 = Frame(window , height = 25 , width = 35 , bg = "light grey" , bd =4 )
frame20.place(x = 310 , y = 385)
field20 = Entry(frame20 , font=("Arial" , 12 , "bold" ) ,textvariable= input_text16 , bg ="white" , justify =LEFT , bd = -1  , width = 5 )
field20.pack()
canva2.place( x = 50 , y = 320)


#******************************************************canvas 3(drink)**************************************************************************************************

input_text8 = IntVar()
input_text9 = IntVar()
input_text10 = IntVar()
input_text11 = IntVar()
input_text12 = IntVar()

canv3 = Canvas(window, height= 200 , width = 320 , bg= "white")

canv3.create_text(160 , 20 ,text="DRINKS",fill = "black" , font = ("Arial Black" , 14  , "underline" , "bold"))

canv3.create_text( 54 , 60 ,text="Milk Shake",fill = "black" , font = ("Cambria Math" , 14 ) )

canv3.create_text( 62 , 90 ,text="Vanilla Cone",fill = "black" , font = ("Cambria Math" , 14 ) )

canv3.create_text( 68 , 120 ,text="Classic Vanilla",fill = "black" , font = ("Cambria Math" , 14 ) )

canv3.create_text( 88 , 150 ,text="Butterscotch Shake",fill = "black" , font = ("Cambria Math" , 14 ) )

canv3.create_text( 56 , 180 ,text="Oreo Shake",fill = "black" , font = ("Cambria Math" , 14 ) )

frame8 = Frame(window , height = 20 , width = 30 ,  bg ="light grey"  , bd = 4 )
frame8.place(x= 660 , y = 150 )

field8 = Entry(frame8 , font=("Arial" , 12 , "bold" ) , bg ="white" , justify =LEFT , bd = -1 , textvariable =input_text8 , width = 3)
field8.pack()

frame9 = Frame(window , height = 20 , width = 30 ,  bg ="light grey"  , bd = 4 )
frame9.place(x= 660 , y = 180 )

field9 = Entry(frame9 , font=("Arial" , 12 , "bold" ) , bg ="white" , justify =LEFT , bd = -1 , textvariable =input_text9 , width = 3)
field9.pack()

frame10 = Frame(window , height = 20 , width = 30 ,  bg ="light grey"  , bd = 4 )
frame10.place(x= 660 , y = 210 )

field10 = Entry(frame10 , font=("Arial" , 12 , "bold" ) , bg ="white" , justify =LEFT , bd = -1 , textvariable =input_text10 , width = 3)
field10.pack()

frame11= Frame(window , height = 20 , width = 30 ,  bg ="light grey"  , bd = 4 )
frame11.place(x= 660 , y = 240 )

field11 = Entry(frame11 , font=("Arial" , 12 , "bold" ) , bg ="white" , justify =LEFT , bd = -1 , textvariable =input_text11 , width = 3)
field11.pack()

frame12 = Frame(window , height = 20 , width = 30 ,  bg ="light grey"  , bd = 4 )
frame12.place(x= 660 , y = 270 ) 

field12 = Entry(frame12 , font=("Arial" , 12 , "bold" ) , bg ="white" , justify =LEFT , bd = -1 , textvariable =input_text12 , width = 3)
field12.pack()


canv3.place(x = 400 , y = 100)



#*********************************************************canvas4(costOfdrink)*****************************************************************************


input_text13 = StringVar()
input_text14= StringVar()
input_text15= StringVar()

canv4 = Canvas(window , height = 100 , width = 320 , bg = "white")


canv4.create_text(28 , 15 , text = "Tax" , font = ("Cambria Math" , 14  ))

frame13 = Frame(window , height = 25 , width = 35 , bg = "light grey" , bd =4 )
frame13.place(x = 660 , y = 325)
field13 = Entry(frame13 , font=("Arial" , 12 , "bold" ) , bg ="white" , justify =LEFT , bd = -1 , textvariable =input_text13 , width = 5)
field13.pack()


canv4.create_text(52 , 45 , text = "Sub Total" , font = ("Cambria Math" , 14  ))

frame14 = Frame(window , height = 25 , width = 35 , bg = "light grey" , bd =4 )
frame14.place(x = 660 , y = 355)
field14 = Entry(frame14 , font=("Arial" , 12 , "bold" ) , textvariable =input_text14 , bg ="white" , justify =LEFT , bd = -1  , width = 5)
field14.pack()


canv4.create_text(33 , 75 , text = "Total" , font = ("Cambria Math" , 14  ))

frame15 = Frame(window , height = 25 , width = 35 , bg = "light grey" , bd =4 )
frame15.place(x = 660 , y = 385)
field15 = Entry(frame15 , font=("Arial" , 12 , "bold" ) , bg ="white" , justify =LEFT , bd = -1 , textvariable =input_text15 , width = 5)
field15.pack()


canv4.place(x = 400 , y = 320)


#*************************************************canvas5(textRecipt)*********************************************************************************


txtReceipt = Text(window , height = 37 , width = 55 , bg ="white"  , font = ("calibri" , 10 , "bold")   )
txtReceipt.place(x = 780 , y = 92 )

#*************************************************canvas6(paidthrough)*********************************************************************************

input_text17 = IntVar()
input_text18 = IntVar()
v = IntVar()
paid = Canvas(window , height = 120 , width = 520 , bg ="white"  )
paid.place(x = 50 , y = 440 )
v= IntVar()
paid.create_text(70 , 30 , text = "Paid through:: " , font = ("Cambria Math" , 14  ))

btn7 = Radiobutton(window, text = "cash"  , variable = v, value = 1)
btn7.place(x = 190 , y = 460)
    
btn6 = Radiobutton(window, text = "debit card" , variable = v  , value = 2 )
btn6.place(x = 245 , y = 460)
    
btn5 = Radiobutton(window, text = "credit card"  , variable = v  , value = 3 )
btn5.place(x = 329 , y = 460)
    
btn8 = Radiobutton(window, text = "UPI" , variable = v , value = 4 )
btn8.place(x = 416 , y = 460)

paid.create_text(90 , 70 , text = "Amount:: " , font = ("Cambria Math" , 14  ))

frame17 = Frame(window , height = 25 , width = 45 , bg = "light grey" , bd =4 )
frame17.place(x = 190 , y = 500)
field17 = Entry(frame17 , font=("Arial" , 12 , "bold" ) , bg ="white" , justify =LEFT , bd = -1 , textvariable =input_text17 , width = 5)
field17.pack()
paid.create_text(270 , 70 , text = "Return:: " , font = ("Cambria Math" , 14  ))

frame18 = Frame(window , height = 25 , width = 45 , bg = "light grey" , bd =4 )
frame18.place(x = 360 , y = 500)
field18 = Entry(frame18 , font=("Arial" , 12 , "bold" ) , bg ="white" , justify =LEFT , bd = -1 , textvariable =input_text18 , width = 5)
field18.pack()


#***********************************************************Buttons***************************************************************

but1_total = Button(window , height = 2 , width = 9 , bg = "grey" , fg ="white" , text = "Total" , activebackground = "silver" , font = ("arial" , 10 , "bold") ,command = lambda :[cost_of_meal() , cost_of_drink() , total_cost() , _tax() , _total()] )
but1_total.place(x = 80 , y = 600)

but2_receipt = Button( window ,height = 2 , width = 9 , bg = "grey" , fg ="white" , text = "Receipt" , activebackground = "silver" , font = ("arial" , 10 , "bold") , command = lambda :[show_data(),return_amount(),add_order()])
but2_receipt.place(x = 210 , y = 600)

but3_reset = Button(window , height = 2 , width = 9 , bg = "grey" , fg ="white" , text = "Reset" , command = lambda :[_clear() ] ,activebackground = "silver" , font = ("arial" , 10 , "bold"))
but3_reset.place(x = 340 , y = 600)

but4_print = Button(window , height = 2 , width = 9 , bg = "grey" , fg ="white" , text = "Print" ,activebackground = "silver" , font = ("arial" , 10 , "bold"))
but4_print.place(x = 470 , y = 600)

but5_exit = Button(window ,height = 2 , width = 9 , bg = "grey" , fg ="white" , text = "Exit" , command = iExit, activebackground = "silver" , font = ("arial" , 10 , "bold"))
but5_exit.place(x = 595 , y = 600)

window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# Cell In[13], line 214
#     210 recepit_ref = StringVar()
#     212 #---------------------------------------------------------------database-----------------------------------------------------------
# --> 214 mydb = mysql.connector.connect(host = "localhost",user = "root",password="@imbharat",database = "personal")
#     215 mycursor = mydb.cursor()
#     217 #**************************************************canvas1(meal)**********************************************************************
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# ...
